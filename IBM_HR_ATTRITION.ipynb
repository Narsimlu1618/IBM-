# %% [markdown]
# ![mygv-ibm-covid-analytics.jpg](attachment:mygv-ibm-covid-analytics.jpg)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
ibm=pd.read_csv("c:\\users\\manne\\Downloads\\Csv files\\IBM HR-Employee-Attrition.csv")

# %%
ibm
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm.shape
# Out:
# (1470, 35)

# %%
ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
ibm.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
ibm.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
ibm.count()
# Out:
# Age                         1470
# Attrition                   1470
# BusinessTravel              1470
# DailyRate                   1470
# Department                  1470
# DistanceFromHome            1470
# Education                   1470
# EducationField              1470
# EmployeeCount               1470
# EmployeeNumber              1470
# EnvironmentSatisfaction     1470
# Gender                      1470
# HourlyRate                  1470
# JobInvolvement              1470
# JobLevel                    1470
# JobRole                     1470
# JobSatisfaction             1470
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# NumCompaniesWorked          1470
# Over18                      1470
# OverTime                    1470
# PercentSalaryHike           1470
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# StockOptionLevel            1470
# ...

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['Age'].shape
# Out:
# (1470,)

# %%
ibm['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
ibm['Age'].nunique()
# Out:
# 43

# %%
ibm['Age'].value_counts()
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64

# %%
ibm[ibm['Age']==35]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 10     35        No      Travel_Rarely        809  Research & Development
# 37     35        No      Travel_Rarely        890                   Sales
# 40     35        No      Travel_Rarely        464  Research & Development
# 49     35        No      Travel_Rarely       1229  Research & Development
# 53     35        No         Non-Travel       1097  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1422   35        No      Travel_Rarely       1490  Research & Development
# 1424   35        No      Travel_Rarely       1395  Research & Development
# 1450   35        No      Travel_Rarely       1146         Human Resources
# 1456   35        No  Travel_Frequently       1199  Research & Development
# 1458   35        No      Travel_Rarely        287  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm[ibm["Age"]==34]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 13     34        No      Travel_Rarely       1346  Research & Development
# 22     34        No      Travel_Rarely        419  Research & Development
# 24     34       Yes      Travel_Rarely        699  Research & Development
# 46     34        No         Non-Travel       1065                   Sales
# 84     34        No      Travel_Rarely       1153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1368   34        No  Travel_Frequently        735  Research & Development
# 1384   34        No      Travel_Rarely        937                   Sales
# 1385   34        No      Travel_Rarely       1239                   Sales
# 1446   34        No      Travel_Rarely        704                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
ibm["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
ibm['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
ibm['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
ibm['BusinessTravel'].isnull().sum()
# Out:
# 0

# %%
ibm['BusinessTravel'].dtype
# Out:
# dtype('O')

# %%
ibm.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
ibm['DailyRate']
# Out:
# 0       1102
# 1        279
# 2       1373
# 3       1392
# 4        591
#         ...
# 1465     884
# 1466     613
# 1467     155
# 1468    1023
# 1469     628
# Name: DailyRate, Length: 1470, dtype: int64

# %%
ibm['DailyRate'].value_counts()
# Out:
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64

# %%
ibm['DailyRate'].unique()
# Out:
# array([1102,  279, 1373, 1392,  591, 1005, 1324, 1358,  216, 1299,  809,
#         153,  670, 1346,  103, 1389,  334, 1123, 1219,  371,  673, 1218,
#         419,  391,  699, 1282, 1125,  691,  477,  705,  924, 1459,  125,
#         895,  813, 1273,  869,  890,  852, 1141,  464, 1240, 1357,  994,
#         721, 1360, 1065,  408, 1211, 1229,  626, 1434, 1488, 1097, 1443,
#         515,  853, 1142,  655, 1115,  427,  653,  989, 1435, 1223,  836,
#        1195, 1339,  664,  318, 1225, 1328, 1082,  548,  132,  746,  776,
#         193,  397,  945, 1214,  111,  573, 1153, 1400,  541,  432,  288,
#         669,  530,  632, 1334,  638, 1093, 1217, 1353,  120,  682,  489,
#         807,  827,  871,  665, 1040, 1420,  240, 1280,  534, 1456,  658,
#         142, 1127, 1031, 1189, 1354, 1467,  922,  394, 1312,  750,  441,
#         684,  249,  841,  147,  528,  594,  470,  957,  542,  802, 1355,
#        1150, 1329,  959, 1033, 1316,  364,  438,  689,  201, 1427,  857,
# ...

# %%
ibm['DailyRate'].nunique()
# Out:
# 886

# %%
ibm['DailyRate'].isnull().sum()
# Out:
# 0

# %%
ibm['DailyRate'].max()
# Out:
# 1499

# %%
ibm['DailyRate'].min()
# Out:
# 102

# %%
ibm['DailyRate'].dtype
# Out:
# dtype('int64')

# %%
ibm.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
ibm['Education']
# Out:
# 0       2
# 1       1
# 2       2
# 3       4
# 4       1
#        ..
# 1465    2
# 1466    1
# 1467    3
# 1468    3
# 1469    3
# Name: Education, Length: 1470, dtype: int64

# %%
ibm['Education'].value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
ibm['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
ibm['Education'].nunique()
# Out:
# 5

# %%
ibm['Education'].dtype
# Out:
# dtype('int64')

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['Department']
# Out:
# 0                        Sales
# 1       Research & Development
# 2       Research & Development
# 3       Research & Development
# 4       Research & Development
#                  ...
# 1465    Research & Development
# 1466    Research & Development
# 1467    Research & Development
# 1468                     Sales
# 1469    Research & Development
# Name: Department, Length: 1470, dtype: object

# %%
ibm['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
ibm["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
ibm['Department'].max()
# Out:
# 'Sales'

# %%
ibm['Department'].min()
# Out:
# 'Human Resources'

# %%
ibm['Department'].nunique()
# Out:
# 3

# %%
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ibm['EnvironmentSatisfaction']
# Out:
# 0       2
# 1       3
# 2       4
# 3       4
# 4       1
#        ..
# 1465    3
# 1466    4
# 1467    2
# 1468    4
# 1469    2
# Name: EnvironmentSatisfaction, Length: 1470, dtype: int64

# %%
ibm['EnvironmentSatisfaction'].unique()
# Out:
# array([2, 3, 4, 1], dtype=int64)

# %%
ibm['EnvironmentSatisfaction'].nunique()
# Out:
# 4

# %%
ibm['EnvironmentSatisfaction'].value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
ibm['EnvironmentSatisfaction'].isnull().sum()
# Out:
# 0

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %%
ibm['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
ibm['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
ibm['Gender'].nunique()
# Out:
# 2

# %%
ibm['Gender'].isnull().sum()
# Out:
# 0

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['JobLevel']
# Out:
# 0       2
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 1465    2
# 1466    3
# 1467    2
# 1468    2
# 1469    2
# Name: JobLevel, Length: 1470, dtype: int64

# %%
ibm['JobLevel'].value_counts()
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %%
ibm['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
ibm['JobLevel'].isnull().sum()
# Out:
# 0

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['JobSatisfaction']
# Out:
# 0       4
# 1       2
# 2       3
# 3       3
# 4       2
#        ..
# 1465    4
# 1466    1
# 1467    2
# 1468    2
# 1469    3
# Name: JobSatisfaction, Length: 1470, dtype: int64

# %%
ibm['JobSatisfaction'].value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
ibm['JobSatisfaction'].unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
ibm['JobSatisfaction'].isnull().sum()
# Out:
# 0

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['MaritalStatus']
# Out:
# 0        Single
# 1       Married
# 2        Single
# 3       Married
# 4       Married
#          ...
# 1465    Married
# 1466    Married
# 1467    Married
# 1468    Married
# 1469    Married
# Name: MaritalStatus, Length: 1470, dtype: object

# %%
ibm['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
ibm['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
ibm['MaritalStatus'].nunique()
# Out:
# 3

# %%
ibm['MaritalStatus'].count()
# Out:
# 1470

# %%
ibm.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 35 columns]

# %%
ibm['MonthlyIncome']
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
ibm['MonthlyIncome'].value_counts()
# Out:
# 2342     4
# 6142     3
# 2741     3
# 2559     3
# 2610     3
#         ..
# 7104     1
# 2773     1
# 19513    1
# 3447     1
# 4404     1
# Name: MonthlyIncome, Length: 1349, dtype: int64

# %%
ibm['MonthlyIncome'].unique()
# Out:
# array([5993, 5130, 2090, ..., 9991, 5390, 4404], dtype=int64)

# %%
ibm['MonthlyIncome'].min()
# Out:
# 1009

# %%
ibm['MonthlyIncome'].max()
# Out:
# 19999

# %%
ibm['MonthlyIncome'].nunique()
# Out:
# 1349

# %%
ibm['MonthlyIncome'].isnull().sum()
# Out:
# 0

# %%
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ibm['WorkLifeBalance']
# Out:
# 0       1
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1465    3
# 1466    3
# 1467    3
# 1468    2
# 1469    4
# Name: WorkLifeBalance, Length: 1470, dtype: int64

# %%
ibm['WorkLifeBalance'].value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
ibm['WorkLifeBalance'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
ibm['WorkLifeBalance'].nunique()
# Out:
# 4

# %%
ibm['WorkLifeBalance'].isnull().sum()
# Out:
# 0

# %%
ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
sns.countplot('Attrition',data=ibm);

# %%
sns.countplot('Education',data=ibm)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(24,8))
sns.countplot('JobRole',data=ibm)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %%
sns.countplot("Gender",data=ibm)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.histplot(ibm['Age'],kde=True);

# %%
sns.countplot(ibm['PercentSalaryHike'])
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %%
sns.barplot(x='Attrition',y='JobLevel',data=ibm);

# %%
sns.barplot(x='Attrition',y='EnvironmentSatisfaction',data=ibm)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='EnvironmentSatisfaction'>

# %%
sns.boxplot(x='Attrition',y='MonthlyIncome',data=ibm)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
sns.boxplot(x='JobLevel',y='MonthlyIncome',data=ibm);

# %%
sns.boxplot(x='MonthlyIncome',y='Department',data=ibm);

# %%
ibm.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
ibm.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
ibm.drop('EmployeeCount',axis=1,inplace=True)
ibm.drop('StandardHours',axis=1,inplace=True)

# %%
ibm.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %%
ibm.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
var_ibm=('Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
       'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager')

# %%
for i in var_ibm:
    ibm[i]=le.fit_transform(ibm[i])

# %%
ibm.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   23          1               2        624           2                 0
# 1   31          0               1        113           1                 7
# 2   19          1               2        805           1                 1
# 3   15          0               1        820           1                 2
# 4    9          0               2        312           1                 1
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# 0          1               1               0                        1  ...
# 1          0               1               1                        2  ...
# 2          1               4               2                        3  ...
# 3          3               1               3                        3  ...
# 4          0               3               4                        0  ...
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
ibm['Attrition'].unique()
# Out:
# array([1, 0])

# %%
final_data=ibm.drop('Attrition',axis=1)

# %%
y=ibm['Attrition']

# %%
dataset=sc.fit_transform(final_data)

# %%
x=pd.DataFrame(dataset,columns=final_data.columns)

# %%
x.head()
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0  0.446350        0.590048   0.713914    1.401512         -1.010909
# 1  1.322365       -0.913194  -1.302446   -0.493817         -0.147150
# 2  0.008343        0.590048   1.428124   -0.493817         -0.887515
# 3 -0.429664       -0.913194   1.487313   -0.493817         -0.764121
# 4 -1.086676        0.590048  -0.517210   -0.493817         -0.887515
#
#    Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0  -0.891688       -0.937414       -1.730873                -0.660531
# 1  -1.868426       -0.937414       -1.728516                 0.254625
# 2  -0.891688        1.316673       -1.726160                 1.169781
# 3   1.061787       -0.937414       -1.723803                 1.169781
# 4  -1.868426        0.565311       -1.721447                -1.575686
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0 -1.224745  ...          -0.426230                 -1.584178
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=24)

# %%
x_train.shape
# Out:
# (1029, 32)

# %%
x_test.shape
# Out:
# (441, 32)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
rf=RandomForestClassifier()
dt=DecisionTreeClassifier()
knn=KNeighborsClassifier()
svm=SVC()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size = 0.3, random_state=42)
for i in[dt, svm, knn, rf]:
    i.fit(x_train, y_train)
    pred = i.predict(x_test)
    test_score = r2_score(y_test, pred)
    train_score = r2_score(y_train, i.predict(x_train))
    if abs(train_score == test_score) <= 0.1:
        print(i)
        print('R2 score is ',r2_score(y_test, pred))
        print('R2 for train data', r2_score(y_train,i.predict(x_train)))
        print('Mean absolute error is',mean_absolute_error(y_test, pred))
        print('Mean squared error is', mean_squared_error(y_test, pred))
        print('Root mean squared error is', (mean_squared_error(y_test, pred, squared=False)))
        print('<====> <====> <=====> <====> <======> <====> <====> <======> <======> <=====> <======> <======>')
# Out:
# DecisionTreeClassifier()
# R2 score is  -0.8073770491803278
# R2 for train data 1.0
# Mean absolute error is 0.21541950113378686
# Mean squared error is 0.21541950113378686
# Root mean squared error is 0.4641330640385221
# <====> <====> <=====> <====> <======> <====> <====> <======> <======> <=====> <======> <======>
# SVC()
# R2 score is  -0.0654012079378774
# R2 for train data 0.4105430033038474
# Mean absolute error is 0.12698412698412698
# Mean squared error is 0.12698412698412698
# Root mean squared error is 0.3563483225498992
# <====> <====> <=====> <====> <======> <====> <====> <======> <======> <=====> <======> <======>
# KNeighborsClassifier()
# R2 score is  -0.08442622950819678
# R2 for train data 0.05412714483640635
# Mean absolute error is 0.1292517006802721
# Mean squared error is 0.1292517006802721
# Root mean squared error is 0.35951592548908334
# <====> <====> <=====> <====> <======> <====> <====> <======> <======> <=====> <======> <======>
# RandomForestClassifier()
# ...
